# %% [markdown]
# <a href="https://colab.research.google.com/github/saravananbass12-tech/-Road-Traffic-Accident-Dashboard-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
a
# Out:
# 10

# %%
import pandas as pd
import matplotlib.pyplot as plt

x = pd.read_csv("programming_languages.csv")

plt.pie(
    x["popularity"],
    labels=x["language"],
    autopct="%1.1f%%",
    startangle=90,
    wedgeprops=dict(width=0.4)
)

plt.title("Programming Language Popularity")
plt.show()
